# %%
# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

# %%
import os
import pandas as pd
from pandas import read_csv
from pandas.plotting import scatter_matrix
from matplotlib import pyplot
from sklearn import model_selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
# load dataset

#import and read json file
json_file = "static/data/ESG_Database.json"
ESG_score_df = pd.read_json(json_file)
ESG_score_df
# Out:
#                        Company Name         HQ City HQ State/Province  \
# MMM                      3M Company      Saint paul         Minnesota
# AOS          A.O. Smith Corporation       Milwaukee         Wisconsin
# ABT             Abbott Laboratories     Abbott park          Illinois
# ABBV                    AbbVie Inc.   North chicago          Illinois
# ABN.AS           ABN AMRO Bank N.V.       Amsterdam     Noord-holland
# ...                             ...             ...               ...
# YUM                Yum! Brands Inc.      Louisville          Kentucky
# ZAYO       Zayo Group Holdings Inc.         Boulder          Colorado
# Z                 Zillow Group Inc.        Guernsey          Guernsey
# ZBH     Zimmer Biomet Holdings Inc.  Warsaw indiana           Indiana
# ZTS             Zoetis Inc. Class A      Parsippany        New jersey
#
#                       HQ Country  ESG Risk Score ESG Risk Score Level  \
# MMM     United states of america              35                 High
# AOS     United states of america              25               Medium
# ABT     United states of america              31                 High
# ABBV    United states of america              30                 High
# ABN.AS               Netherlands              86               Severe
# ...                          ...             ...                  ...
# YUM     United states of america              20               Medium
# ZAYO    United states of america              30               Medium
# Z                       Guernsey              30                 High
# ZBH     United states of america              34                 High
# ZTS     United states of america              28               Medium
#
#        ESG Risk Score Percentile  Environment Risk Score  Social Risk Score  \
# MMM              69th percentile                    12.6               12.7
# AOS              37th percentile                    13.6                4.3
# ABT              57th percentile                     3.7               15.3
# ABBV             56th percentile                     1.0               16.5
# ABN.AS           98th percentile                    90.0               85.0
# ...                          ...                     ...                ...
# YUM              21st percentile                     4.1               10.9
# ZAYO             53rd percentile                     8.8               12.5
# Z                55th percentile                     3.3               15.8
# ZBH              67th percentile                     3.8               18.5
# ZTS              48th percentile                     2.7               13.9
#
#         Governance Risk Score  ...                 Exchange  \
# MMM                       9.2  ...  New York Stock Exchange
# AOS                       7.3  ...  New York Stock Exchange
# ABT                      11.6  ...  New York Stock Exchange
# ABBV                     12.8  ...  New York Stock Exchange
# ABN.AS                   84.0  ...                Amsterdam
# ...                       ...  ...                      ...
# YUM                       5.3  ...  New York Stock Exchange
# ZAYO                      8.3  ...  New York Stock Exchange
# Z                        11.1  ...     Nasdaq Global Select
# ZBH                      11.5  ...  New York Stock Exchange
# ZTS                      11.6  ...  New York Stock Exchange
#
#                         CEO  \
# MMM          Inge G. Thulin
# AOS                    None
# ABT          Miles D. White
# ABBV    Richard A. Gonzalez
# ABN.AS                 None
# ...                     ...
# YUM              Greg Creed
# ZAYO       Daniel P. Caruso
# Z        Spencer M. Rascoff
# ZBH         Bryan C. Hanson
# ZTS        Juan Ramon Alaix
#
#                                            Logo Image URL  \
# MMM     https://financialmodelingprep.com/images-New-j...
# AOS     https://financialmodelingprep.com/images-New-j...
# ABT     https://financialmodelingprep.com/images-New-j...
# ABBV    https://financialmodelingprep.com/images-New-j...
# ABN.AS  https://financialmodelingprep.com/images-New-j...
# ...                                                   ...
# YUM     https://financialmodelingprep.com/images-New-j...
# ZAYO    https://financialmodelingprep.com/images-New-j...
# Z       https://financialmodelingprep.com/images-New-j...
# ZBH     https://financialmodelingprep.com/images-New-j...
# ZTS     https://financialmodelingprep.com/images-New-j...
#
#                         Website URL                 Industry  \
# MMM               http://www.3m.com      Industrial Products
# AOS          http://www.aosmith.com      Industrial Products
# ABT           http://www.abbott.com       Drug Manufacturers
# ABBV          http://www.abbvie.com       Drug Manufacturers
# ABN.AS       http://www.abnamro.com        Banks—Diversified
# ...                             ...                      ...
# YUM              http://www.yum.com              Restaurants
# ZAYO            http://www.zayo.com  Communication Equipment
# Z        http://www.zillowgroup.com     Real Estate Services
# ZBH     http://www.zimmerbiomet.com          Medical Devices
# ZTS           http://www.zoetis.com       Drug Manufacturers
#
#                     Sector                                Company Description  \
# MMM            Industrials  3M Co is a diversified technology company. It ...
# AOS            Industrials  A.O. Smith Corp manufactures and markets water...
# ABT             Healthcare  Abbott Laboratories is a health care company t...
# ABBV            Healthcare  AbbVie Inc is a biopharmaceutical company that...
# ABN.AS  Financial Services  ABN AMRO Bank N.V. provides various banking pr...
# ...                    ...                                                ...
# YUM      Consumer Cyclical  Yum Brands Inc is engaged in operating quick-s...
# ZAYO            Technology  Zayo Group Holdings Inc provides fiber-based c...
# Z              Real Estate  Zillow Group Inc provides real estate and home...
# ZBH             Healthcare  Zimmer Biomet Holdings Inc is a medical device...
# ZTS             Healthcare  Zoetis Inc is a developer and manufacturer of ...
#
#          Latitude   Longitude                                          address
# MMM     44.953703  -93.089958    Saint paul,Minnesota,United states of america
# AOS     43.038902  -87.906474     Milwaukee,Wisconsin,United states of america
# ABT     42.304181  -87.896392    Abbott park,Illinois,United states of america
# ABBV    42.325578  -87.841182  North chicago,Illinois,United states of america
# ABN.AS  52.366697    4.894540              Amsterdam,Noord-holland,Netherlands
# ...           ...         ...                                              ...
# YUM     38.252665  -85.758456     Louisville,Kentucky,United states of america
# ZAYO    40.014986 -105.270546        Boulder,Colorado,United states of america
# Z       33.791638  -84.389488                                             None
# ZBH     41.238100  -85.853047  Warsaw indiana,Indiana,United states of america
# ZTS     40.865287  -74.417388   Parsippany,New jersey,United states of america
#
# [724 rows x 23 columns]

# %%
ESG_data = ESG_score_df[['ESG Risk Score','Environment Risk Score', 'Social Risk Score', 'Governance Risk Score','ESG Risk Score Level']].copy()
ESG_data
# Out:
#         ESG Risk Score  Environment Risk Score  Social Risk Score  \
# MMM                 35                    12.6               12.7
# AOS                 25                    13.6                4.3
# ABT                 31                     3.7               15.3
# ABBV                30                     1.0               16.5
# ABN.AS              86                    90.0               85.0
# ...                ...                     ...                ...
# YUM                 20                     4.1               10.9
# ZAYO                30                     8.8               12.5
# Z                   30                     3.3               15.8
# ZBH                 34                     3.8               18.5
# ZTS                 28                     2.7               13.9
#
#         Governance Risk Score ESG Risk Score Level
# MMM                       9.2                 High
# AOS                       7.3               Medium
# ABT                      11.6                 High
# ABBV                     12.8                 High
# ABN.AS                   84.0               Severe
# ...                       ...                  ...
# YUM                       5.3               Medium
# ZAYO                      8.3               Medium
# Z                        11.1                 High
# ZBH                      11.5                 High
# ZTS                      11.6               Medium
#
# [724 rows x 5 columns]

# %%
# shape
print(ESG_data.shape)
# Out:
# (724, 5)

# %%
# descriptions
print(ESG_data.describe())
# Out:
#        ESG Risk Score  Environment Risk Score  Social Risk Score  \
# count      724.000000              724.000000         724.000000
# mean        24.747238                6.807182          10.822928
# std          9.595465                8.590472           7.017971
# min          7.000000                0.000000           1.000000
# 25%         18.000000                1.600000           7.400000
# 50%         23.000000                4.000000          10.000000
# 75%         31.000000                9.625000          12.900000
# max         86.000000               90.000000          88.000000
#
#        Governance Risk Score
# count             724.000000
# mean                8.423343
# std                 6.927881
# min                 3.300000
# 25%                 6.000000
# 50%                 7.100000
# 75%                 9.000000
# max                90.000000

# %%
# class distribution
print(ESG_data.groupby('ESG Risk Score Level').size())
# Out:
# ESG Risk Score Level
# High          118
# Low           178
# Medium        246
# Negligible    102
# Severe         80
# dtype: int64

# %%
from matplotlib.pyplot import figure

#Data Visualization to check distribution of data 
# box and whisker plots
ESG_data.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)
figure(num=None, figsize=(8, 6), dpi=80)
pyplot.show()

# %%
#more visiulization of data
# histograms
ESG_data.hist()
figure(num=None, figsize=(8, 6), dpi=80)
pyplot.show()

# %%
#check interaction between veriables
# scatter plot matrix
scatter_matrix(ESG_data)
figure(num=None, figsize=(8, 6), dpi=80)
pyplot.show()

# %%
# Evaluate Algorithmes
#validate data
# Split-out validation dataset
array = ESG_data.values
X = array[:,0:4]
y = array[:,4]
X_train, X_validation, Y_train, Y_validation = train_test_split(X, y, test_size=0.20, random_state=1)

# %%
models = []
models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('TREE', DecisionTreeClassifier()))
models.append(('RF', RandomForestClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC(gamma='auto')))
# evaluate each model in turn
results = []
ESG_datas = []
for ESG_data, model in models:
    kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy')
    results.append(cv_results)
    ESG_datas.append(ESG_data)
    print('%s: %f (%f)' % (ESG_data, cv_results.mean(), cv_results.std()))
# Out:
# LR: 0.624938 (0.042530)
# LDA: 0.731948 (0.037733)
# KNN: 0.735926 (0.019707)
# TREE: 0.821303 (0.045487)
# RF: 0.832455 (0.040501)
# NB: 0.661582 (0.037079)
# SVM: 0.756264 (0.023556)

# %%
#check models for best selection
#Compare Algorithms
pyplot.boxplot(results, labels=ESG_datas)
pyplot.title('Algorithm Comparison')
pyplot.show()


# lab_enc = preprocessing.LabelEncoder()
# encoded = lab_enc.fit_transform(trainingScores)
# array([1, 3, 2, 0], dtype=int64)

# %%
# Make predictions on validation dataset
model = SVC(gamma='auto')
model.fit(X_train, Y_train)
predictions = model.predict(X_validation)

# %%
# Evaluate predictions
print(accuracy_score(Y_validation, predictions))
print(confusion_matrix(Y_validation, predictions))
print(classification_report(Y_validation, predictions))
# Out:
# 0.696551724137931
# [[20  0  2  0  6]
#  [ 0 27  2  2  0]
#  [ 0  3 45  0  0]
#  [ 0 18  1  7  0]
#  [ 7  0  3  0  2]]
#               precision    recall  f1-score   support
#
#         High       0.74      0.71      0.73        28
#          Low       0.56      0.87      0.68        31
#       Medium       0.85      0.94      0.89        48
#   Negligible       0.78      0.27      0.40        26
#       Severe       0.25      0.17      0.20        12
#
#     accuracy                           0.70       145
#    macro avg       0.64      0.59      0.58       145
# weighted avg       0.70      0.70      0.67       145

# %%
# Import required packages
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('ESG_Database_Cleaned.csv')
data.head()
# Out:
#    Ticker            Company Name        HQ City HQ State/Province  \
# 0     MMM              3M Company     Saint paul         Minnesota
# 1     AOS  A.O. Smith Corporation      Milwaukee         Wisconsin
# 2     ABT     Abbott Laboratories    Abbott park          Illinois
# 3    ABBV             AbbVie Inc.  North chicago          Illinois
# 4  ABN.AS      ABN AMRO Bank N.V.      Amsterdam     Noord-holland
#
#                  HQ Country  ESG Risk Score ESG Risk Score Level  \
# 0  United states of america              35                 High
# 1  United states of america              25               Medium
# 2  United states of america              31                 High
# 3  United states of america              30                 High
# 4               Netherlands              86               Severe
#
#   ESG Risk Score Percentile  Environment Risk Score  Social Risk Score  ...  \
# 0           69th percentile                    12.6               12.7  ...
# 1           37th percentile                    13.6                4.3  ...
# 2           57th percentile                     3.7               15.3  ...
# 3           56th percentile                     1.0               16.5  ...
# 4           98th percentile                    90.0               85.0  ...
#
#    Controversy Level Risk Text 2019 Performance    Market Cap  \
# 0                  Significant        -7.410517  9.350000e+10
# 1                     Moderate        11.569087  7.090000e+09
# 2                  Significant        20.088483  1.580000e+11
# 3                  Significant        -3.959215  1.210000e+11
# 4                  Significant       -21.032132  1.490000e+10
#
#                   Exchange                  CEO  \
# 0  New York Stock Exchange       Inge G. Thulin
# 1  New York Stock Exchange                  NaN
# 2  New York Stock Exchange       Miles D. White
# 3  New York Stock Exchange  Richard A. Gonzalez
# 4                Amsterdam                  NaN
#
#                                       Logo Image URL             Website URL  \
# 0  https://financialmodelingprep.com/images-New-j...       http://www.3m.com
# 1  https://financialmodelingprep.com/images-New-j...  http://www.aosmith.com
# 2  https://financialmodelingprep.com/images-New-j...   http://www.abbott.com
# 3  https://financialmodelingprep.com/images-New-j...   http://www.abbvie.com
# 4  https://financialmodelingprep.com/images-New-j...  http://www.abnamro.com
#
#               Industry              Sector  \
# 0  Industrial Products         Industrials
# 1  Industrial Products         Industrials
# 2   Drug Manufacturers          Healthcare
# 3   Drug Manufacturers          Healthcare
# 4    Banks—Diversified  Financial Services
#
#                                  Company Description
# 0  3M Co is a diversified technology company. It ...
# 1  A.O. Smith Corp manufactures and markets water...
# 2  Abbott Laboratories is a health care company t...
# 3  AbbVie Inc is a biopharmaceutical company that...
# 4  ABN AMRO Bank N.V. provides various banking pr...
#
# [5 rows x 21 columns]

# %%
ESG_df = data[['Environment Risk Score', 'Social Risk Score', 'Governance Risk Score']].copy()
ESG_df
# ESG_data = ['Environment Risk Score', 'Social Risk Score', 'Governance Risk Score']
# Out:
#      Environment Risk Score  Social Risk Score  Governance Risk Score
# 0                      12.6               12.7                    9.2
# 1                      13.6                4.3                    7.3
# 2                       3.7               15.3                   11.6
# 3                       1.0               16.5                   12.8
# 4                      90.0               85.0                   84.0
# ..                      ...                ...                    ...
# 718                     4.1               10.9                    5.3
# 719                     8.8               12.5                    8.3
# 720                     3.3               15.8                   11.1
# 721                     3.8               18.5                   11.5
# 722                     2.7               13.9                   11.6
#
# [723 rows x 3 columns]

# %%
print(ESG_df.describe())
# Out:
#        Environment Risk Score  Social Risk Score  Governance Risk Score
# count              723.000000         723.000000             723.000000
# mean                 6.790318          10.826833               8.422545
# std                  8.584418           7.022043               6.932644
# min                  0.000000           1.000000               3.300000
# 25%                  1.600000           7.400000               6.000000
# 50%                  4.000000          10.000000               7.100000
# 75%                  9.550000          12.900000               9.000000
# max                 90.000000          88.000000              90.000000

# %%
mms = MinMaxScaler()
mms.fit(ESG_df)
ESG_df_transformed = mms.transform(ESG_df)

# %%
Sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(ESG_df_transformed)
    Sum_of_squared_distances.append(km.inertia_)

# %%
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_blobs
# generate 2d classification dataset
X, y = make_blobs(n_samples=100, centers=2, n_features=2, random_state=1)
# fit final model
model = LogisticRegression()
model.fit(X, y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# new instances where we do not know the answer
Xnew, _ = make_blobs(n_samples=3, centers=2, n_features=2, random_state=1)
# make a prediction
ynew = model.predict(Xnew)

# show the inputs and predicted outputs
for i in range(len(Xnew)):
    print("X=%s, Predicted=%s" % (Xnew[i], ynew[i]))
# Out:
# X=[-0.79415228  2.10495117], Predicted=0
# X=[-8.25290074 -4.71455545], Predicted=1
# X=[-2.18773166  3.33352125], Predicted=0

# %%
# define one new data instance
Xnew = [[-1.07296862, -0.52817175]]
# make a prediction
ynew = model.predict(Xnew)
# show the inputs and predicted outputs
print("X=%s, Predicted=%s" % (Xnew[0], ynew[0]))
# Out:
# X=[-1.07296862, -0.52817175], Predicted=1

# %%
# import joblib
# filename = 'Rina_T.sav'
# joblib.dump(model, filename)

# %%
# Out:
# C:\Users\rinat\Anaconda3\lib\site-packages\ipykernel_launcher.py:47: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
