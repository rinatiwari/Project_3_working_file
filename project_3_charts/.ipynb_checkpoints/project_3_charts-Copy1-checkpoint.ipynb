# %%
from splinter import Browser
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import time

# %%
def init_browser():
    # @NOTE: Replace the path with your actual path to the chromedriver
    executable_path = {"executable_path": "chromedriver.exe"}
    return browser("chrome", **executable_path, headless=False)

# %%
# def scrape_info():
#browser = Browser('chrome')
#browser = init_browser()
yahoo_stock = {}

# %%
# Visit finance.yahoo.com
browser = Browser('chrome')
browser.visit("https://finance.yahoo.com/")
time.sleep(5)

# %%
# Scrape page into Soup
html = browser.html
soup = bs(html, "html.parser")

# %%
# Get the stock information
stock_info = soup.findAll("table", {"class": "W(100%)"})
print(stock_info)
# Out:
# [<table class="W(100%) Pos(r) Tbl(f) Bdcl(c) BdB Bdc($c-fuji-grey-c)" data-reactid="49"><thead data-reactid="50"><tr class="C($c-fuji-grey-j) BdB Bxz(bb) Bdc($c-fuji-grey-c)" data-reactid="51"><th class="Whs(nw) Py(6px) Ta(start) Fz(xs) Va(m) Py(5px) Fw(400) Ta(start) Pend(10px)" data-reactid="52"><span data-reactid="53">Symbol</span></th><th class="Whs(nw) Ta(end) Pstart(10px) Py(6px) Fz(xs) Va(m) Py(5px) Fw(400)" data-reactid="54"><span data-reactid="55">Last Price</span></th><th class="Whs(nw) Ta(end) Pstart(10px) Py(6px) Fz(xs) Va(m) Py(5px) Fw(400)" data-reactid="56"><span data-reactid="57">Change</span></th><th class="Whs(nw) Ta(end) Pstart(10px) Py(6px) Fz(xs) Va(m) Py(5px) Fw(400)" data-reactid="58"><span data-reactid="59">% Change</span></th></tr></thead><tbody data-reactid="60"><tr class="dt-row Bgc($extraLightBlue):h BdB Bdbc($finLightGrayAlt) Bdbc($tableBorderBlue):h H(44px)"><td class="Va(t) Fz(14px) Whs(nw) Py(6px) Ta(start) Start(0) Pend(10px)"><a class="Fw(b) Ell D(b)" href="/quote/BTC-USD?p=BTC-USD" title="Bitcoin USD">BTC-USD</a><p class="Fz(xs) Pt(2px) M(0) C($c-fuji-grey-j) Pos(a) Fw(400)! Ell Maw(220px)" title="Bitcoin USD">Bitcoin USD</p></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500)">9,619.36</span></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500) C($dataRed)">-299.71</span></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500) C($dataRed)">-3.02%</span></td></tr><tr class="dt-row Bgc($extraLightBlue):h BdB Bdbc($finLightGrayAlt) Bdbc($tableBorderBlue):h H(44px)"><td class="Va(t) Fz(14px) Whs(nw) Py(6px) Ta(start) Start(0) Pend(10px)"><a class="Fw(b) Ell D(b)" href="/quote/ETH-USD?p=ETH-USD" title="Ethereum USD">ETH-USD</a><p class="Fz(xs) Pt(2px) M(0) C($c-fuji-grey-j) Pos(a) Fw(400)! Ell Maw(220px)" title="Ethereum USD">Ethereum USD</p></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500)">264.20</span></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500) C($dataRed)">-9.39</span></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500) C($dataRed)">-3.43%</span></td></tr><tr class="dt-row Bgc($extraLightBlue):h BdB Bdbc($finLightGrayAlt) Bdbc($tableBorderBlue):h H(44px)"><td class="Va(t) Fz(14px) Whs(nw) Py(6px) Ta(start) Start(0) Pend(10px)"><a class="Fw(b) Ell D(b)" href="/quote/XRP-USD?p=XRP-USD" title="XRP USD">XRP-USD</a><p class="Fz(xs) Pt(2px) M(0) C($c-fuji-grey-j) Pos(a) Fw(400)! Ell Maw(220px)" title="XRP USD">XRP USD</p></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500)">0.2688</span></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500) C($dataRed)">-0.0141</span></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500) C($dataRed)">-4.99%</span></td></tr><tr class="dt-row Bgc($extraLightBlue):h BdB Bdbc($finLightGrayAlt) Bdbc($tableBorderBlue):h H(44px)"><td class="Va(t) Fz(14px) Whs(nw) Py(6px) Ta(start) Start(0) Pend(10px)"><a class="Fw(b) Ell D(b)" href="/quote/BCH-USD?p=BCH-USD" title="Bitcoin Cash USD">BCH-USD</a><p class="Fz(xs) Pt(2px) M(0) C($c-fuji-grey-j) Pos(a) Fw(400)! Ell Maw(220px)" title="Bitcoin Cash USD">Bitcoin Cash USD</p></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500)">372.22</span></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500) C($dataRed)">-28.01</span></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500) C($dataRed)">-7.00%</span></td></tr><tr class="dt-row Bgc($extraLightBlue):h BdB Bdbc($finLightGrayAlt) Bdbc($tableBorderBlue):h H(44px)"><td class="Va(t) Fz(14px) Whs(nw) Py(6px) Ta(s ...

# %%
import pandas as pd

#<span class="Va(m)" data-reactid="739"><span data-reactid="740">Next</span></span>

for i in range (0,1):
    stock_info_df = pd.read_html('https://finance.yahoo.com/most-active?offset=0&count=197')[i]
    stock_info_df.columns=['Ticker', 'Name', 'Price', 'Change', '% Change', 'Market Cap', 'Volume in Currency(UTF)', 
                       'Volume in Currency(24hrs)', 'Total Volume All Currencies', 'Circulating Supply']
stock_info_df.set_index('Ticker', inplace=True)
stock_info_df
# Out:
#                                     Name    Price  Change % Change Market Cap  \
# Ticker
# F                     Ford Motor Company    7.620 -0.2600   -3.36%    82.681M
# AMD         Advanced Micro Devices, Inc.   50.000 -3.2800   -6.16%    70.703M
# GE              General Electric Company   11.880 -0.3700   -2.99%    53.197M
# BAC          Bank of America Corporation   32.830 -1.5300   -4.44%     51.59M
# MSFT               Microsoft Corporation  173.500 -5.0900   -2.85%    50.258M
# ...                                  ...      ...     ...      ...        ...
# RLLCF           Rolls-Royce Holdings plc    0.006 -0.0003   -4.76%     7.305M
# COG          Cabot Oil & Gas Corporation   15.020  0.1300   +0.91%     7.263M
# AMAT             Applied Materials, Inc.   61.590 -2.6800   -4.17%     7.294M
# RDS-A              Royal Dutch Shell plc   47.560 -1.6100   -3.28%      7.21M
# OXY     Occidental Petroleum Corporation   40.190 -1.9300   -4.58%     7.169M
#
#        Volume in Currency(UTF) Volume in Currency(24hrs)  \
# Ticker
# F                       50.66M                   30.233B
# AMD                    52.765M                   58.483B
# GE                      56.72M                  103.787B
# BAC                    43.653M                  286.601B
# MSFT                   26.464M                     1.32T
# ...                        ...                       ...
# RLLCF                   5.153M                  130.804B
# COG                     7.917M                     5.98B
# AMAT                    7.171M                   56.558B
# RDS-A                   3.676M                  175.204B
# OXY                    10.039M                   35.902B
#
#         Total Volume All Currencies  Circulating Supply
# Ticker
# F                            762.50                 NaN
# AMD                          166.67                 NaN
# GE                              NaN                 NaN
# BAC                           11.94                 NaN
# MSFT                          30.22                 NaN
# ...                             ...                 ...
# RLLCF                           NaN                 NaN
# COG                            9.17                 NaN
# AMAT                          20.43                 NaN
# RDS-A                         12.19                 NaN
# OXY                           29.42                 NaN
#
# [100 rows x 9 columns]
