# %%
from splinter import Browser
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import time

# %%
def init_browser():
    # @NOTE: Replace the path with your actual path to the chromedriver
    executable_path = {"executable_path": "chromedriver.exe"}
    return browser("chrome", **executable_path, headless=False)

# %%
# def scrape_info():
#browser = Browser('chrome')
#browser = init_browser()
yahoo_stock = {}

# %%
# Visit finance.yahoo.com
browser = Browser('chrome')
browser.visit("https://finance.yahoo.com/")
time.sleep(5)

# %%
# Scrape page into Soup
html = browser.html
soup = bs(html, "html.parser")

# %%
# Get the stock information
stock_info = soup.find("table", {"class": "W(100%)"})
print(stock_info)
# Out:
# <table class="W(100%) Pos(r) Tbl(f) Bdcl(c) BdB Bdc($c-fuji-grey-c)" data-reactid="49"><thead data-reactid="50"><tr class="C($c-fuji-grey-j) BdB Bxz(bb) Bdc($c-fuji-grey-c)" data-reactid="51"><th class="Whs(nw) Py(6px) Ta(start) Fz(xs) Va(m) Py(5px) Fw(400) Ta(start) Pend(10px)" data-reactid="52"><span data-reactid="53">Symbol</span></th><th class="Whs(nw) Ta(end) Pstart(10px) Py(6px) Fz(xs) Va(m) Py(5px) Fw(400)" data-reactid="54"><span data-reactid="55">Last Price</span></th><th class="Whs(nw) Ta(end) Pstart(10px) Py(6px) Fz(xs) Va(m) Py(5px) Fw(400)" data-reactid="56"><span data-reactid="57">Change</span></th><th class="Whs(nw) Ta(end) Pstart(10px) Py(6px) Fz(xs) Va(m) Py(5px) Fw(400)" data-reactid="58"><span data-reactid="59">% Change</span></th></tr></thead><tbody data-reactid="60"><tr class="dt-row Bgc($extraLightBlue):h BdB Bdbc($finLightGrayAlt) Bdbc($tableBorderBlue):h H(44px)"><td class="Va(t) Fz(14px) Whs(nw) Py(6px) Ta(start) Start(0) Pend(10px)"><a class="Fw(b) Ell D(b)" href="/quote/BTC-USD?p=BTC-USD" title="Bitcoin USD">BTC-USD</a><p class="Fz(xs) Pt(2px) M(0) C($c-fuji-grey-j) Pos(a) Fw(400)! Ell Maw(220px)" title="Bitcoin USD">Bitcoin USD</p></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500)">9,781.38</span></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500) C($dataRed)">-137.69</span></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500) C($dataRed)">-1.39%</span></td></tr><tr class="dt-row Bgc($extraLightBlue):h BdB Bdbc($finLightGrayAlt) Bdbc($tableBorderBlue):h H(44px)"><td class="Va(t) Fz(14px) Whs(nw) Py(6px) Ta(start) Start(0) Pend(10px)"><a class="Fw(b) Ell D(b)" href="/quote/ETH-USD?p=ETH-USD" title="Ethereum USD">ETH-USD</a><p class="Fz(xs) Pt(2px) M(0) C($c-fuji-grey-j) Pos(a) Fw(400)! Ell Maw(220px)" title="Ethereum USD">Ethereum USD</p></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500)">270.37</span></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500) C($dataRed)">-3.22</span></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500) C($dataRed)">-1.18%</span></td></tr><tr class="dt-row Bgc($extraLightBlue):h BdB Bdbc($finLightGrayAlt) Bdbc($tableBorderBlue):h H(44px)"><td class="Va(t) Fz(14px) Whs(nw) Py(6px) Ta(start) Start(0) Pend(10px)"><a class="Fw(b) Ell D(b)" href="/quote/XRP-USD?p=XRP-USD" title="XRP USD">XRP-USD</a><p class="Fz(xs) Pt(2px) M(0) C($c-fuji-grey-j) Pos(a) Fw(400)! Ell Maw(220px)" title="XRP USD">XRP USD</p></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500)">0.2740</span></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500) C($dataRed)">-0.0089</span></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500) C($dataRed)">-3.14%</span></td></tr><tr class="dt-row Bgc($extraLightBlue):h BdB Bdbc($finLightGrayAlt) Bdbc($tableBorderBlue):h H(44px)"><td class="Va(t) Fz(14px) Whs(nw) Py(6px) Ta(start) Start(0) Pend(10px)"><a class="Fw(b) Ell D(b)" href="/quote/BCH-USD?p=BCH-USD" title="Bitcoin Cash USD">BCH-USD</a><p class="Fz(xs) Pt(2px) M(0) C($c-fuji-grey-j) Pos(a) Fw(400)! Ell Maw(220px)" title="Bitcoin Cash USD">Bitcoin Cash USD</p></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500)">388.56</span></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500) C($dataRed)">-11.67</span></td><td class="Va(t) Fz(14px) Whs(nw) Ta(end) Pstart(10px) Py(6px)"><span class="Trsdu(0.3s) Fw(500) C($dataRed)">-2.91%</span></td></tr><tr class="dt-row Bgc($extraLightBlue):h BdB Bdbc($finLightGrayAlt) Bdbc($tableBorderBlue):h H(44px)"><td class="Va(t) Fz(14px) Whs(nw) Py(6px) Ta(st ...

# %%
import pandas as pd
stock_info_df = pd.read_html('https://finance.yahoo.com/most-active?offset=0&count=197')[0]
stock_info_df.columns=['Ticker', 'Name', 'Price', 'Change', '% Change', 'Market Cap', 'Volume in Currency(UTF)', 
                       'Volume in Currency(24hrs)', 'Total Volume All Currencies', 'Circulating Supply']
stock_info_df.set_index('Ticker', inplace=True)
stock_info_df
# Out:
#                                       Name   Price  Change % Change  \
# Ticker
# S                       Sprint Corporation   10.05    0.57   +6.01%
# AMD           Advanced Micro Devices, Inc.   53.28   -3.99   -6.97%
# F                       Ford Motor Company    7.89   -0.14   -1.74%
# MSFT                 Microsoft Corporation  178.59   -5.83   -3.16%
# DBX                          Dropbox, Inc.   22.45    3.74  +19.96%
# ...                                    ...     ...     ...      ...
# LYG               Lloyds Banking Group plc    2.83   -0.05   -1.74%
# SAN                  Banco Santander, S.A.    4.04   -0.10   -2.42%
# AGNC                 AGNC Investment Corp.   19.26   -0.36   -1.83%
# HPE     Hewlett Packard Enterprise Company   14.18   -0.29   -2.00%
# GM                  General Motors Company   34.65   -0.64   -1.81%
#
#        Market Cap Volume in Currency(UTF) Volume in Currency(24hrs)  \
# Ticker
# S        111.246M                 23.179M                    41.32B
# AMD       88.553M                 52.765M                   62.319B
# F         58.326M                  50.66M                   31.283B
# MSFT        48.6M                 26.464M                    1.358T
# DBX       48.277M                  5.038M                    9.324B
# ...           ...                     ...                       ...
# LYG        8.698M                  6.946M                   50.483B
# SAN        8.594M                  7.708M                   67.799B
# AGNC       8.569M                  5.118M                   10.419B
# HPE         8.48M                  8.693M                   18.337B
# GM         8.432M                  9.605M                   49.515B
#
#         Total Volume All Currencies  Circulating Supply
# Ticker
# S                               NaN                 NaN
# AMD                          177.60                 NaN
# F                            789.00                 NaN
# MSFT                          31.11                 NaN
# DBX                             NaN                 NaN
# ...                             ...                 ...
# LYG                            9.43                 NaN
# SAN                            8.38                 NaN
# AGNC                          16.60                 NaN
# HPE                           18.42                 NaN
# GM                             7.58                 NaN
#
# [100 rows x 9 columns]
