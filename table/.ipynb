# %%
# import dependencies 
import os
import pandas as pd
from sqlalchemy import create_engine

# %%
#import and read second csv file
csv_file = "ESG_Database_cleaned.csv"
ESG_score_df = pd.read_csv(csv_file)
ESG_score_df.head()
# Out:
#          Ticker            Company Name        HQ City HQ State/Province  \
# 0  <<<<<<< HEAD                     NaN            NaN               NaN
# 1           MMM              3M Company     Saint paul         Minnesota
# 2           AOS  A.O. Smith Corporation      Milwaukee         Wisconsin
# 3           ABT     Abbott Laboratories    Abbott park          Illinois
# 4          ABBV             AbbVie Inc.  North chicago          Illinois
#
#                  HQ Country  ESG Risk Score ESG Risk Score Level  \
# 0                       NaN             NaN                  NaN
# 1  United states of america            35.0                 High
# 2  United states of america            25.0               Medium
# 3  United states of america            31.0                 High
# 4  United states of america            30.0                 High
#
#   ESG Risk Score Percentile  Environment Risk Score  Social Risk Score  ...  \
# 0                       NaN                     NaN                NaN  ...
# 1           69th percentile                    12.6               12.7  ...
# 2           37th percentile                    13.6                4.3  ...
# 3           57th percentile                     3.7               15.3  ...
# 4           56th percentile                     1.0               16.5  ...
#
#                   Exchange                  CEO  \
# 0                      NaN                  NaN
# 1  New York Stock Exchange       Inge G. Thulin
# 2  New York Stock Exchange                  NaN
# 3  New York Stock Exchange       Miles D. White
# 4  New York Stock Exchange  Richard A. Gonzalez
#
#                                       Logo Image URL             Website URL  \
# 0                                                NaN                     NaN
# 1  https://financialmodelingprep.com/images-New-j...       http://www.3m.com
# 2  https://financialmodelingprep.com/images-New-j...  http://www.aosmith.com
# 3  https://financialmodelingprep.com/images-New-j...   http://www.abbott.com
# 4  https://financialmodelingprep.com/images-New-j...   http://www.abbvie.com
#
#               Industry       Sector  \
# 0                  NaN          NaN
# 1  Industrial Products  Industrials
# 2  Industrial Products  Industrials
# 3   Drug Manufacturers   Healthcare
# 4   Drug Manufacturers   Healthcare
#
#                                  Company Description   Latitude  Longitude  \
# 0                                                NaN        NaN        NaN
# 1  3M Co is a diversified technology company. It ...  44.953703 -93.089958
# 2  A.O. Smith Corp manufactures and markets water...  43.038902 -87.906474
# 3  Abbott Laboratories is a health care company t...  42.304181 -87.896392
# 4  AbbVie Inc is a biopharmaceutical company that...  42.325578 -87.841182
#
#                                            address
# 0                                              NaN
# 1    Saint paul,Minnesota,United states of america
# 2     Milwaukee,Wisconsin,United states of america
# 3    Abbott park,Illinois,United states of america
# 4  North chicago,Illinois,United states of america
#
# [5 rows x 24 columns]

# %%
# # generate path to csv
# csv_path = os.path.join('static/data', 'ESG_Database_cleaned.csv')
# ESG_Database_cleaned_csv = pd.read_csv(csv_path)

# %%
# #create connection with database engine
# connection_string = "postgres:postgres@localhost:5432/ESG_tbl_DB"
# engine = create_engine(f'postgresql://{connection_string}')

# %%
# #check table
# engine.table_names()
# Out:
# ['ESG_tbl_DB']

# %%
# #load dataframe "us review" into database
# ESG_table.to_sql(name='ESG_tbl_DB', con=engine, if_exists='append', index=False)

# %%
# create html table and save to file 
ESG_Database_cleaned_csv.to_html('table.html', index=False, classes=['table', 'table-striped', 'table-hover'])
